# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('dog_backpack.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.imread('watermark_no_copy.png')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1=cv2.resize(img1,(1200,1200))
img2=cv2.resize(img2,(1200,1200))

# %%
b_img = cv2.addWeighted(src1 = img1,alpha = 0.9 ,src2 = img2 ,beta= 0.2,gamma= 0)
plt.imshow(b_img)

# %%
img1 = cv2.resize(img1,(600,600))
plt.imshow(img1)

# %%
# Out:
# (600, 3)

# %%
img1 = cv2.imread('dog_backpack.jpg')
img2 = cv2.imread('watermark_no_copy.png')

# %%
img1= cv2.resize(img1, (1200,1200))
img2= cv2.resize(img2, (1200,1200))

# %%
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
small_img = cv2.resize(img2,(600,600))
big_img = img1

# %%
x_offset = 300
y_offset = 300

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
small_img.shape
# Out:
# (600, 600, 3)

# %%
big_img[y_offset:y_end,x_offset:x_end] = small_img
plt.imshow(big_img)

# %%
img1 = cv2.imread('dog_backpack.jpg')
img2 = cv2.imread('watermark_no_copy.png')
img2 = cv2.resize(img2,(600,600))
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(img1)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
x_offset = 934 - 600
y_offset = 1401-600
